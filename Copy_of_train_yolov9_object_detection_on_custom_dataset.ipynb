# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/train-yolov9-model/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Mar 17 09:23:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 325, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 325 (delta 134), reused 102 (delta 102), pack-reused 153
# Receiving objects: 100% (325/325), 2.26 MiB | 5.60 MiB/s, done.
# Resolving deltas: 100% (159/159), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 68.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 79.5 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install the [`roboflow`](https://pypi.org/project/roboflow) package, which we will use to download our dataset from [Roboflow Universe](https://universe.roboflow.com/).

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.4 MB/s eta 0:00:00

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions `yolov9-s` and `yolov9-m` are also mentioned, but the weights for these models are not yet available in the YOLOv9 [repository](https://github.com/WongKinYiu/yolov9).

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Mar 17 09:25 .
# drwxr-xr-x 1 root root      4096 Mar 17 09:25 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %% [markdown]
# **NOTE:** If you want to run inference using your own file as input, simply upload image to Google Colab and update `SOURCE_IMAGE_PATH` with the path leading to your file.

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
SOURCE_IMAGE_PATH = f"{HOME}/dog.jpeg"

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 handbag, 132.3ms
# Speed: 0.5ms pre-process, 132.3ms inference, 649.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp/dog.jpeg", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 166.4ms
# Speed: 0.4ms pre-process, 166.4ms inference, 641.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9
# Out:
# /content/yolov9

# %% [markdown]
# **NOTE:** In this tutorial, I will use the [football-players-detection](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc) dataset. Feel free to replace it with your dataset in YOLO format or use another dataset available on [Roboflow Universe](https://universe.roboflow.com). Additionally, if you plan to deploy your model to Roboflow after training, make sure you are the owner of the dataset and that no model is associated with the version of the dataset you are going to training on.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Gjp3wYaZVQHza4Nk1uHw")
project = rf.workspace("nishith-ranjan-biswas").project("vehicle-detection-2-oxhfc")
version = project.version(3)
dataset = version.download("yolov9")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.24)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2023.7.22)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.25.2)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.4.27)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.49.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Vehicle-detection-2-3 to yolov9:: 100%|██████████| 179368/179368 [00:05<00:00, 30536.97it/s]
# Extracting Dataset Version Zip to Vehicle-detection-2-3 in yolov9:: 100%|██████████| 6356/6356 [00:01<00:00, 3852.29it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 50 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-03-17 09:26:47.704646: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 09:26:47.704735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 09:26:47.814052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-17 09:26:49.085896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/Vehicle-detection-2-3/data.yaml, hyp=hyp.scratch-high.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 27.7MB/s]
# Overriding model.yaml nc=80 with nc=8
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5496808  models.yolo.DDetect                     [8, [256, 512, 512]]
# gelan-c summary: 621 layers, 25443240 parameters, 25443224 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/Vehicle-detection-2-3/train/labels... 2234 images, 54 backgrounds, 0 corrupt: 100% 2234/2234 [00:01<00:00, 1627.31it/s]
# train: New cache created: /content/yolov9/Vehicle-detection-2-3/train/labels.cache
# val: Scanning /content/yolov9/Vehicle-detection-2-3/valid/labels... 627 images, 12 backgrounds, 0 corrupt: 100% 627/627 [00:00<00:00, 1505.50it/s]
# val: New cache created: /content/yolov9/Vehicle-detection-2-3/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/49      13.7G      1.863      2.246      1.584         58        640: 100% 140/140 [02:10<00:00,  1.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100%
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/49      15.5G       1.41     0.7303      1.436         51        640: 100% 140/140 [01:50<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:15<00:00,  1.29it/s]
#                    all        627       3489       0.71      0.632      0.675       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/49      15.5G      1.402     0.7193       1.43         26        640: 100% 140/140 [01:49<00:00,  1.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:15<00:00,  1.31it/s]
#                    all        627       3489      0.692      0.645      0.681      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/49      15.5G      1.388     0.7012      1.438         46        640: 100% 140/140 [01:49<00:00,  1.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:15<00:00,  1.26it/s]
#                    all        627       3489      0.727      0.634      0.679      0.321
#
# 50 epochs completed in 1.828 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.5MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.5MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:21<00:00,  1.09s/it]
#                    all        627       3489      0.714      0.647      0.681      0.328
#                    bus        627        413      0.773      0.725      0.772      0.413
#                    car        627       1244      0.822      0.758      0.831      0.412
#                    cng        627        343      0.749      0.635      0.697      0.343
#              micro_bus        627         43      0.399      0.324      0.275      0.155
#             motor_bike        627        405      0.745      0.642      0.681      0.262
#               rickshaw        627        621      0.766      0.676      0.737      0.323
#             thela_gari        627          6      0.704      0.667      0.671      0.303
#                  truck        627        414      0.758      0.749      0.787      0.413
# Results saved to runs/train/exp

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1710667609.91bdb61bbe2f.1367.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image

Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 32 --conf 0.001 --iou 0.7 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/Vehicle-detection-2-3/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.7, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/Vehicle-detection-2-3/valid/labels.cache... 627 images, 12 backgrounds, 0 corrupt: 100% 627/627 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 20/20 [00:30<00:00,  1.55s/it]
#                    all        627       3489      0.731      0.647      0.681      0.328
#                    bus        627        413      0.773      0.725      0.771      0.413
#                    car        627       1244      0.822      0.758      0.831      0.413
#                    cng        627        343      0.749      0.635      0.697      0.341
#              micro_bus        627         43      0.399      0.324      0.275      0.155
#             motor_bike        627        405      0.749      0.642      0.682      0.262
#               rickshaw        627        621      0.765      0.675      0.736      0.324
#             thela_gari        627          6      0.839      0.667       0.67      0.303
#                  truck        627        414      0.756      0.746      0.782      0.415
# Speed: 0.3ms pre-process, 34.5ms inference, 4.6ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/test/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/Vehicle-detection-2-3/test/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25417128 parameters, 0 gradients, 102.5 GFLOPs
# image 1/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-101-_jpg.rf.9999859140e1131f7ce8b8c60de764a8.jpg: 1280x1280 1 bus, 1 car, 1 cng, 1 motor_bike, 6 rickshaws, 113.5ms
# image 2/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-1024-_jpg.rf.bfb85c6571a13f25de91f97909d9e97a.jpg: 1280x1280 1 bus, 8 cars, 2 cngs, 1 truck, 112.2ms
# image 3/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-1039-_jpg.rf.efedefa6c0341dbb097844b1b0a896c6.jpg: 1280x1280 5 cars, 1 cng, 4 motor_bikes, 2 trucks, 112.5ms
# image 4/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-1040-_jpg.rf.be89790f2adfa0c7a052b3e3e83fb6e9.jpg: 1280x1280 1 bus, 3 cars, 2 motor_bikes, 1 rickshaw, 4 trucks, 113.5ms
# image 5/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-1054-_jpg.rf.94441bdfdc563ba31ce5cfcd5e3d3417.jpg: 1280x1280 1 car, 2 motor_bikes, 113.2ms
# image 180/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3006-_jpg.rf.84df2fb36cf40c4d15534f532459cb20.jpg: 1280x1280 1 car, 1 cng, 118.2ms
# image 181/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3008-_jpg.rf.a5eff4c4d33dfc3ca0a2ad3a58d2e941.jpg: 1280x1280 1 car, 1 cng, 3 rickshaws, 117.2ms
# image 182/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3013-_jpg.rf.d0ab956ab33279f8845e6abc359122b3.jpg: 1280x1280 2 cngs, 116.2ms
# image 183/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3041-_jpg.rf.fbada398f00d53d59f755c1d0b16e91a.jpg: 1280x1280 1 bus, 1 car, 2 cngs, 2 rickshaws, 119.2ms
# image 184/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3044-_jpg.rf.9a22792c5cd107a8e9fc90dee61d68f2.jpg: 1280x1280 2 buss, 1 car, 1 cng, 1 truck, 117.5ms
# image 185/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3076-_jpg.rf.5e0140cdd1eb54f3194fe8590b4a1d81.jpg: 1280x1280 3 cars, 3 micro_buss, 1 rickshaw, 2 trucks, 119.6ms
# image 186/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3079-_jpg.rf.b32c981e469062e3f8b2ee32468867b6.jpg: 1280x1280 10 cars, 1 cng, 20 motor_bikes, 18 rickshaws, 117.7ms
# image 187/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3088-_jpg.rf.4ad64ed89c69cace7d7041cb8ac6d34a.jpg: 1280x1280 1 bus, 13 cars, 2 cngs, 21 motor_bikes, 36 rickshaws, 1 truck, 119.7ms
# image 188/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3096-_jpg.rf.c8acdcc853c3045142151e56b1d7ecfa.jpg: 1280x1280 1 car, 1 motor_bike, 1 rickshaw, 117.6ms
# image 189/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-310-_jpg.rf.d28995a78ad73fcf990c976fef97e8b4.jpg: 1280x1280 2 buss, 26 cars, 6 cngs, 5 motor_bikes, 3 rickshaws, 2 trucks, 119.3ms
# image 190/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3109-_jpg.rf.d83e5c7b447ef7ad76575b3c279ebd3d.jpg: 1280x1280 3 cars, 1 rickshaw, 118.3ms
# image 191/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3124-_jpg.rf.e92340038e6174990f5dea336caa98eb.jpg: 1280x1280 (no detections), 118.7ms
# image 192/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3128-_jpg.rf.fd40ba5fa2680676036b6636f745cca3.jpg: 1280x1280 1 car, 1 thela_gari, 121.2ms
# image 193/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3134-_jpg.rf.36abea7ffba5912eb81b83ccd8ac4692.jpg: 1280x1280 2 cars, 1 motor_bike, 118.3ms
# image 194/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3140-_jpg.rf.476427166f6c797c9ab152122547e844.jpg: 1280x1280 1 car, 1 motor_bike, 1 truck, 119.8ms
# image 195/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3147-_jpg.rf.5db9ec2d862dceaa9f5c0e7bd977d662.jpg: 1280x1280 6 cars, 3 motor_bikes, 2 trucks, 119.2ms
# image 196/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3151-_jpg.rf.48182010ae5a266ea118490662163f7c.jpg: 1280x1280 1 bus, 1 car, 2 motor_bikes, 3 rickshaws, 1 truck, 117.4ms
# image 197/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3157-_jpg.rf.686cdc10193837bfeeaa9bb96caad6a0.jpg: 1280x1280 1 car, 1 cng, 2 motor_bikes, 6 rickshaws, 2 trucks, 119.2ms
# image 198/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3158-_jpg.rf.1a77e7a579f14a5c76ba75b6c467a6c4.jpg: 1280x1280 2 buss, 2 cars, 118.8ms
# image 199/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3194-_jpg.rf.4ce94ee5c9612ccef28ab18eb4e73689.jpg: 1280x1280 1 rickshaw, 3 trucks, 119.3ms
# image 200/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3196-_jpg.rf.5f5d8781635d03b67403211302db7862.jpg: 1280x1280 2 cars, 1 motor_bike, 1 truck, 118.5ms
# image 201/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3214-_jpg.rf.84b183d17b63579f04e8cb28b434b575.jpg: 1280x1280 1 bus, 9 cars, 118.6ms
# image 202/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3223-_jpg.rf.fb1060c67988c26fad65c7f5ae74dd64.jpg: 1280x1280 1 bus, 4 cars, 3 cngs, 1 rickshaw, 117.9ms
# image 203/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-323-_jpg.rf.c03f173b6d2d7d3504379a7640244e22.jpg: 1280x1280 2 buss, 2 rickshaws, 120.5ms
# image 204/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3261-_jpg.rf.21f9316287a2a7202a67d61d8f183af5.jpg: 1280x1280 3 buss, 4 rickshaws, 1 truck, 120.3ms
# image 205/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3274-_jpg.rf.c6c8c0a81a8f9e03f11b524a410497c3.jpg: 1280x1280 14 rickshaws, 1 truck, 117.4ms
# image 206/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3287-_jpg.rf.ba9ecbdb83af3f9afcc9537e0e8f0617.jpg: 1280x1280 4 rickshaws, 2 trucks, 118.5ms
# image 207/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3336-_jpg.rf.506f0ef5e47a7cc9f75e6b6cff2c19b8.jpg: 1280x1280 3 buss, 1 car, 1 rickshaw, 2 trucks, 119.1ms
# image 223/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3448-_jpg.rf.5fd924205e4ff1a210146d3b38e43557.jpg: 1280x1280 4 cars, 1 motor_bike, 117.4ms
# image 224/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3450-_jpg.rf.d9af419e93d5fc6c6188fd05392ef92f.jpg: 1280x1280 1 bus, 5 cars, 1 cng, 2 motor_bikes, 1 rickshaw, 117.2ms
# image 225/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3460-_jpg.rf.e252a40906a3f881ba5ed97c46ee40c2.jpg: 1280x1280 10 cars, 3 cngs, 3 motor_bikes, 1 rickshaw, 119.4ms
# image 226/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3461-_jpg.rf.4c9da3b51814ee13816d1af0cebd1b04.jpg: 1280x1280 1 bus, 2 cars, 2 cngs, 3 motor_bikes, 2 rickshaws, 117.4ms
# image 227/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3474-_jpg.rf.3087603036648c0ad7eab1294c40d637.jpg: 1280x1280 6 cars, 1 cng, 4 motor_bikes, 118.4ms
# image 228/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-348-_jpg.rf.faf80c290c65e9988cbf76e328cb2dbb.jpg: 1280x1280 1 bus, 4 cars, 4 cngs, 2 motor_bikes, 4 rickshaws, 118.0ms
# image 229/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3481-_jpg.rf.a6c02e040bd4709c66142942c146fefb.jpg: 1280x1280 2 buss, 2 cars, 1 cng, 1 motor_bike, 1 truck, 117.3ms
# image 230/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3496-_jpg.rf.a3f2ec53a6b19aadfe394dd13a0669a3.jpg: 1280x1280 1 bus, 5 cars, 1 cng, 2 motor_bikes, 2 trucks, 119.1ms
# image 231/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3500-_jpg.rf.c64b189a7294d3c95559e665f5661b66.jpg: 1280x1280 2 buss, 2 cars, 2 cngs, 1 motor_bike, 1 truck, 117.3ms
# image 232/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-352-_jpg.rf.eda31ff00ea02569d99046250a5aabee.jpg: 1280x1280 7 cars, 2 cngs, 1 motor_bike, 1 rickshaw, 117.3ms
# image 233/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3524-_jpg.rf.35187226d95007094225656ecd9c3e9d.jpg: 1280x1280 6 cars, 3 rickshaws, 1 truck, 119.1ms
# image 234/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3530-_jpg.rf.5f0a2805a6a2be70554ef98392fc5d19.jpg: 1280x1280 4 buss, 3 cars, 3 motor_bikes, 117.7ms
# image 235/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3540-_jpg.rf.9f5e792d7c9ce8f1a00383cc49013bf3.jpg: 1280x1280 2 buss, 8 cars, 119.0ms
# image 236/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3558-_jpg.rf.e01f25801de6f7858b58ea0f25116ede.jpg: 1280x1280 1 bus, 1 cng, 9 rickshaws, 2 trucks, 117.9ms
# image 237/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3573-_jpg.rf.23dd5043ea175432175ac35a08f6af96.jpg: 1280x1280 1 car, 2 trucks, 116.5ms
# image 238/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3579-_jpg.rf.8fd800a6394cb76417f6309cf51fd9de.jpg: 1280x1280 1 bus, 1 car, 1 rickshaw, 2 trucks, 117.8ms
# image 239/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3589-_jpg.rf.a79c63bc540985460a2698aeb928cb88.jpg: 1280x1280 1 bus, 1 car, 1 motor_bike, 3 rickshaws, 3 trucks, 117.6ms
# image 240/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-359-_jpg.rf.9865bf734c3df63ffb73f627073efab2.jpg: 1280x1280 2 buss, 9 rickshaws, 118.3ms
# image 241/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3591-_jpg.rf.38c313db6919fa42467056dc69211f83.jpg: 1280x1280 1 car, 3 trucks, 118.5ms
# image 242/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3592-_jpg.rf.020ffdce04ace904bec3d2eb96ecfa2b.jpg: 1280x1280 1 bus, 1 car, 3 trucks, 118.5ms
# image 243/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3607-_jpg.rf.ce01f5f8c212345fd974580fa679c555.jpg: 1280x1280 3 cars, 1 motor_bike, 1 rickshaw, 118.2ms
# image 244/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3650-_jpg.rf.2902fd62218992d230dea4035ce93d1c.jpg: 1280x1280 7 cars, 2 cngs, 1 rickshaw, 1 truck, 117.1ms
# image 245/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3656-_jpg.rf.3e9229c26877e35cff7684269b9bef85.jpg: 1280x1280 6 cars, 1 cng, 1 truck, 118.2ms
# image 246/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3659-_jpg.rf.2a17e5dd452a876f6d50de2104e31d33.jpg: 1280x1280 7 cars, 1 cng, 3 rickshaws, 1 truck, 118.0ms
# image 247/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3669-_jpg.rf.fc35c7f301ec9aba61a2f023b2736eca.jpg: 1280x1280 7 cars, 1 rickshaw, 1 truck, 117.9ms
# image 248/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3671-_jpg.rf.e09b6488a34ce65b0230f4f8361edc95.jpg: 1280x1280 3 cars, 1 motor_bike, 1 rickshaw, 118.6ms
# image 249/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3672-_jpg.rf.adebe19e0a80e8a599ffcbc5833da55d.jpg: 1280x1280 2 buss, 1 car, 1 motor_bike, 3 rickshaws, 119.2ms
# image 250/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3679-_jpg.rf.b4d239c603fe682c46d86d1f3597ec91.jpg: 1280x1280 2 cars, 1 motor_bike, 1 rickshaw, 116.7ms
# image 251/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-368-_jpg.rf.a1850959beb3b1a026eccb0116456cbd.jpg: 1280x1280 1 car, 8 rickshaws, 117.3ms
# image 252/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3682-_jpg.rf.0ecab80935c6169ce6f9ab5d8385683d.jpg: 1280x1280 2 buss, 2 cars, 2 motor_bikes, 1 rickshaw, 116.3ms
# image 253/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3697-_jpg.rf.4907e844b5e0a39ece519a59afab4796.jpg: 1280x1280 3 cars, 1 cng, 1 motor_bike, 1 rickshaw, 120.2ms
# image 254/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3708-_jpg.rf.7c73c10a4576cb98989970d50f62cec3.jpg: 1280x1280 2 cars, 1 motor_bike, 1 rickshaw, 117.6ms
# image 255/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3712-_jpg.rf.dc7f6950d50ccdeec6a4d390b4ddcdef.jpg: 1280x1280 2 cars, 1 cng, 2 motor_bikes, 116.5ms
# image 256/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3714-_jpg.rf.2a0c1cffa87942c778a6f8ad73e7e2ce.jpg: 1280x1280 3 cars, 1 cng, 2 motor_bikes, 1 rickshaw, 1 truck, 116.1ms
# image 257/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3717-_jpg.rf.b0f5d44790e60394eccf4e39e191b8bc.jpg: 1280x1280 2 cars, 2 cngs, 3 motor_bikes, 1 rickshaw, 116.4ms
# image 258/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-3724-_jpg.rf.16603e183080fba34c00ca31a221eb9a.jpg: 1280x1280 2 cars, 1 cng, 2 motor_bikes, 1 rickshaw, 117.9ms
# image 259/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-39-_jpg.rf.d5ea2aaf00975f9033ac322b6b7ea9cc.jpg: 1280x1280 2 cngs, 4 motor_bikes, 116.5ms
# image 260/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-415-_jpg.rf.df7e829f7d5f6a8221d12e02d610b91d.jpg: 1280x1280 2 buss, 1 car, 6 rickshaws, 2 trucks, 118.3ms
# image 261/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-425-_jpg.rf.d319d0d97e14c7ecd740b2fcb51f4d07.jpg: 1280x1280 1 micro_bus, 1 truck, 116.2ms
# image 262/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-43-_jpg.rf.28be0ed74347e560884afd92c49d7552.jpg: 1280x1280 1 car, 1 cng, 4 motor_bikes, 117.1ms
# image 263/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-440-_jpg.rf.0124efb303c2e73e119350b48a3efc94.jpg: 1280x1280 2 buss, 3 rickshaws, 4 trucks, 118.8ms
# image 264/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-461-_jpg.rf.8e117a755661842acaee7068c8b972dc.jpg: 1280x1280 6 rickshaws, 117.6ms
# image 265/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-465-_jpg.rf.574c7b14e8d7e5e957e022714435fd8c.jpg: 1280x1280 7 cars, 1 micro_bus, 2 motor_bikes, 1 rickshaw, 118.0ms
# image 266/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-467-_jpg.rf.26af922aa39849eec7c6c6bafc93f031.jpg: 1280x1280 3 cars, 6 rickshaws, 116.7ms
# image 267/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-48-_jpg.rf.69a7fa7720dd17e7868684fb8e697e8b.jpg: 1280x1280 1 car, 2 cngs, 6 motor_bikes, 1 rickshaw, 2 trucks, 117.7ms
# image 268/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-496-_jpg.rf.6b2a2f6055f438fb8e5239b5f3ebc803.jpg: 1280x1280 1 bus, 5 trucks, 116.4ms
# image 269/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-508-_jpg.rf.03865dde53045b732a00070217c3fdcd.jpg: 1280x1280 3 trucks, 115.7ms
# image 270/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-514-_jpg.rf.42f593383d84ef9bf4af360ea783a06a.jpg: 1280x1280 3 buss, 3 trucks, 116.3ms
# image 271/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-527-_jpg.rf.99eff9d1125d1123c8e0c29cbb027595.jpg: 1280x1280 6 trucks, 115.6ms
# image 272/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-537-_jpg.rf.cc9c030c40894a55adb0f68d6d859bc1.jpg: 1280x1280 3 buss, 3 trucks, 117.1ms
# image 273/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-550-_jpg.rf.582ba7f69a4f8a04a48703eedb063014.jpg: 1280x1280 4 buss, 1 car, 1 micro_bus, 3 trucks, 117.5ms
# image 274/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-582-_jpg.rf.44f42fa42ecd86f8cc8f36f9bc0148a1.jpg: 1280x1280 2 buss, 8 cars, 1 cng, 3 motor_bikes, 1 rickshaw, 116.7ms
# image 275/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-594-_jpg.rf.fbd2acc35d38030bd6d1e31a7e0814dc.jpg: 1280x1280 2 buss, 9 cars, 1 cng, 1 motor_bike, 2 trucks, 116.8ms
# image 276/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-60-_jpg.rf.18f398d66fecbf10ca7643106fd65b5f.jpg: 1280x1280 2 cars, 3 rickshaws, 116.7ms
# image 277/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-604-_jpg.rf.710bbb48501ccc7de386c4e86fb7a4e4.jpg: 1280x1280 3 buss, 1 truck, 117.0ms
# image 278/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-611-_jpg.rf.b6fc3919232106f1266c7650ba0dc709.jpg: 1280x1280 1 car, 1 rickshaw, 2 trucks, 117.5ms
# image 279/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-615-_jpg.rf.4805f4da45abdfd06fd851eee4db7def.jpg: 1280x1280 6 buss, 1 car, 1 micro_bus, 1 truck, 117.5ms
# image 280/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-618-_jpg.rf.5bd13d6f8f7c45109bb79f44006a3b7b.jpg: 1280x1280 3 buss, 1 car, 1 motor_bike, 2 trucks, 116.0ms
# image 281/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-626-_jpg.rf.19dc7f621d9c83af72550f7c24da194f.jpg: 1280x1280 3 buss, 1 car, 1 cng, 1 truck, 116.8ms
# image 282/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-638-_jpg.rf.eac0e62e7c533b51de77bee2cf3e5434.jpg: 1280x1280 1 bus, 3 cars, 3 motor_bikes, 117.4ms
# image 283/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-649-_jpg.rf.d379a43720d6ef62e9df39cde13097c9.jpg: 1280x1280 2 buss, 2 cars, 2 motor_bikes, 1 truck, 117.2ms
# image 284/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-687-_jpg.rf.a63fae10eafcd18c452160a5431e2aa1.jpg: 1280x1280 1 bus, 1 car, 3 cngs, 1 motor_bike, 118.3ms
# image 285/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-692-_jpg.rf.81f5260195a53e60ca1531f86437ac99.jpg: 1280x1280 1 bus, 2 cars, 3 cngs, 116.7ms
# image 286/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-707-_jpg.rf.3d77ca6da6e5d54b5007e74243a87e62.jpg: 1280x1280 1 car, 2 cngs, 2 motor_bikes, 117.1ms
# image 287/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-713-_jpg.rf.2b0c87d1383b823e69f3d57b66b6a79a.jpg: 1280x1280 2 cars, 2 cngs, 1 motor_bike, 1 truck, 116.1ms
# image 288/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-724-_jpg.rf.ed5cdb14510470f17ee64205651e60b3.jpg: 1280x1280 5 cars, 1 cng, 1 motor_bike, 116.8ms
# image 289/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-725-_jpg.rf.97dc2ff9a1fec5f311f3a1cb73f396c3.jpg: 1280x1280 4 cars, 2 motor_bikes, 116.7ms
# image 290/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-737-_jpg.rf.1d9d0c5430d5ef3a11a62f18b0930f8e.jpg: 1280x1280 2 buss, 1 car, 1 cng, 2 motor_bikes, 1 truck, 116.4ms
# image 291/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-746-_jpg.rf.3745ad936aa5a511e38d592dbc0f8550.jpg: 1280x1280 1 bus, 3 cars, 3 cngs, 116.3ms
# image 292/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-750-_jpg.rf.fb0ad74c14f38cc933fd4bc648481fe8.jpg: 1280x1280 3 cars, 1 cng, 1 micro_bus, 1 motor_bike, 116.9ms
# image 293/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-752-_jpg.rf.bd2c73eea68b6f436d10c9685b275564.jpg: 1280x1280 2 buss, 3 cars, 2 cngs, 1 micro_bus, 1 motor_bike, 116.0ms
# image 294/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-774-_jpg.rf.c373204581f1fd9feea06c1fcaa185ec.jpg: 1280x1280 2 buss, 1 cng, 1 rickshaw, 116.9ms
# image 295/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-777-_jpg.rf.a59966d8a4c2438aab1854a68727d525.jpg: 1280x1280 5 buss, 2 cars, 1 motor_bike, 116.7ms
# image 296/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-78-_jpg.rf.05fb7e1abb47d3cf92084414f0df973f.jpg: 1280x1280 3 cars, 1 cng, 1 motor_bike, 116.7ms
# image 297/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-781-_jpg.rf.f1c7ba7725d537113a1aca338695a6f1.jpg: 1280x1280 1 bus, 1 car, 1 cng, 2 motor_bikes, 115.7ms
# image 298/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-8-_jpg.rf.d730464770fa62c96ae73d0acaf37603.jpg: 1280x1280 2 cngs, 116.1ms
# image 299/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-803-_jpg.rf.ef4ce125cf27daa0a66bc2694581940e.jpg: 1280x1280 5 cars, 1 cng, 1 motor_bike, 117.1ms
# image 300/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-816-_jpg.rf.03566d1e25dd948e0943c3ed447f8be9.jpg: 1280x1280 5 cars, 1 cng, 1 micro_bus, 2 motor_bikes, 1 truck, 116.6ms
# image 301/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-839-_jpg.rf.8c3cc5b7ef105c4a7cf9fe2f77a49f77.jpg: 1280x1280 1 bus, 7 cars, 1 motor_bike, 116.1ms
# image 302/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-871-_jpg.rf.b87930c99728e0de61841ea917084b20.jpg: 1280x1280 9 cars, 1 cng, 1 motor_bike, 116.3ms
# image 303/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-872-_jpg.rf.dc87384b52730870c67abae78493f3af.jpg: 1280x1280 9 cars, 1 cng, 116.1ms
# image 304/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-879-_jpg.rf.5abf8623155412369dac64a0a72eef0e.jpg: 1280x1280 2 buss, 7 cars, 116.2ms
# image 305/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-921-_jpg.rf.ccb45862c29b7d6fc770d6df24a80e1b.jpg: 1280x1280 3 cars, 4 motor_bikes, 116.7ms
# image 306/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-926-_jpg.rf.ee5d07056c238a001a686348f48b829a.jpg: 1280x1280 2 buss, 6 cars, 1 motor_bike, 116.6ms
# image 307/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-941-_jpg.rf.d53f092cb0e09c529cef121bb0d4ca26.jpg: 1280x1280 7 cars, 5 motor_bikes, 116.5ms
# image 308/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-952-_jpg.rf.4885188a3d73f61f94764dd502525aa1.jpg: 1280x1280 1 bus, 8 cars, 1 micro_bus, 5 motor_bikes, 2 rickshaws, 115.9ms
# image 309/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-96-_jpg.rf.c4449767e4089eb527e06314894a2c7c.jpg: 1280x1280 1 bus, 1 car, 3 rickshaws, 115.6ms
# image 310/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-971-_jpg.rf.64d8100d82537336685dd53302d712ee.jpg: 1280x1280 8 cars, 3 motor_bikes, 115.1ms
# image 311/311 /content/yolov9/Vehicle-detection-2-3/test/images/image-977-_jpg.rf.1644b14fbc1a50586ed84558ba7495ea.jpg: 1280x1280 2 buss, 1 car, 2 motor_bikes, 5 rickshaws, 116.5ms
# Speed: 1.8ms pre-process, 116.4ms inference, 3.2ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp3

# %% [markdown]
# **NOTE:** Just like behore, the inference results have been saved in the appropriate directory inside `{HOME}/yolov9/runs/detect/`. Let's examine few of those results.

# %%
import glob

from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp3/*.jpg')[:2]:
      display(Image(filename=image_path, width=600))

# %% [markdown]
# ## BONUS: Deploy YOLOv9 Model with Inference

# %% [markdown]
# **NOTE:** To deploy the model and display inference results, we will need two additional packages - [`inference`](https://pypi.org/project/inference) and [`supervision`](https://pypi.org/project/supervision). Let's install and import them!

# %%
# !pip install -q inference supervision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.6/332.6 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.8/251.8 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.7/239.7 kB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 32.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 46.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.9/746.9 kB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 41.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 70.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 100.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 87.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 114.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 96.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 99.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 100.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 108.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 102.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 109.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 107.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 66.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 80.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 76.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 79.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 72.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 94.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 100.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 105.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 105.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 111.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 70.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 110.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 108.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 110.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 95.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 79.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 67.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 87.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 109.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 82.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 108.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 111.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 110.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 94.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 73.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 75.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 76.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 73.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 109.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 98.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 75.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 73.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 80.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 79.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 70.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 66.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 102.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 108.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 86.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 51.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 110.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 105.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 104.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 105.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 112.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 111.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 103.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 113.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 111.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 79.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 60.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 77.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 79.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 68.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 101.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 93.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 67.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 91.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 39.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 107.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 103.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 111.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 109.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 90.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 85.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 99.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 96.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 100.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 109.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 96.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 95.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 109.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 90.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 101.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 100.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 64.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 94.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 95.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 112.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 107.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 107.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 96.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 84.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 116.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 94.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 114.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 109.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 39.3 MB/s eta 0:00:00
#   Building wheel for GPUtil (setup.py) ... done

# %%
import cv2
import random
import getpass

import supervision as sv

from inference import get_model

# %matplotlib inline

# %% [markdown]
# **NOTE:** Before using your model in Inference, you first need to upload your weights to Roboflow Universe. Ensure to specify the correct `model_type` - `yolov9`, and that the project version matches the version of the dataset you used for training, denoted by `[1]`. In my case, it's `6`.
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/upload-roboflow-model.png)

# %%
version.deploy(model_type="yolov9", model_path=f"{HOME}/yolov9/runs/train/exp")
# Out:
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/6
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/model/6

# %% [markdown]
# **NOTE:** Now we can download our model anywhere using the assigned `model_id` denoted by `[2]`. In my case `football-players-detection-3zvbc/6`. To download the model you will need your [`ROBOFLOW_API_KEY`](https://docs.roboflow.com/api-reference/authentication).

# %%
ROBOFLOW_API_KEY = getpass.getpass()

model = get_model(model_id="football-players-detection-3zvbc/8", api_key=ROBOFLOW_API_KEY)
# Out:
# ··········

# %% [markdown]
# **NOTE:** Let's pick random image from our test subset and detect objects using newly fine-tuned model.

# %%
image_paths = sv.list_files_with_extensions(
    directory=f"{dataset.location}/test/images",
    extensions=['png', 'jpg', 'jpeg']
)
image_path = random.choice(image_paths)
image = cv2.imread(image_path)

result = model.infer(image, confidence=0.1)[0]
detections = sv.Detections.from_inference(result)

# %% [markdown]
# **NOTE:** Finally, let's use supervision and [annotate](https://supervision.roboflow.com/develop/annotators/) our results.

# %%
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)
bounding_box_annotator = sv.BoundingBoxAnnotator()

annotated_image = image.copy()
annotated_image = bounding_box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
